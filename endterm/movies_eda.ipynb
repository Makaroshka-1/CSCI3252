# %% [markdown]
# # EDA on dataset

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import re 


df = pd.read_csv("movies_dataset.csv")
df.head()
# Out:
# /var/folders/cv/57_q_p5n4cncc53s74r1mjy80000gn/T/ipykernel_30886/2825589379.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# 0        Inception  Cobb, a skilled thief who commits corporate es...
# 1     Interstellar  The adventures of a group of explorers who mak...
# 2  The Dark Knight  Batman raises the stakes in his war on crime. ...
# 3           Avatar  In the 22nd century, a paraplegic Marine is di...
# 4     The Avengers  When an unexpected enemy emerges and threatens...
#
#   popularity                       poster_path  \
# 0     83.952  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1    140.241  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2    130.643  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3     79.932  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4     98.082   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords
# 0  rescue, mission, dream, airplane, paris, franc...
# 1  rescue, future, spacecraft, race against time,...
# 2  joker, sadism, chaos, secret identity, crime f...
# 3  future, society, culture clash, space travel, ...
# 4  new york city, superhero, shield, based on com...
#
# [5 rows x 24 columns]

# %%
num_movies = df.shape[0]
num_movies
# Out:
# 1136234

# %%
df.describe()
# Out:
#                  id  vote_average    vote_count       revenue       runtime  \
# count  1.136234e+06  1.136234e+06  1.136234e+06  1.136234e+06  1.136234e+06
# mean   7.403880e+05  1.880607e+00  1.887721e+01  6.909537e+05  4.777739e+01
# std    3.957063e+05  3.021621e+00  3.185670e+02  1.792533e+07  6.168211e+01
# min    2.000000e+00  0.000000e+00  0.000000e+00 -1.200000e+01 -2.800000e+01
# 25%    4.107642e+05  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    7.452860e+05  0.000000e+00  0.000000e+00  0.000000e+00  2.300000e+01
# 75%    1.091715e+06  4.800000e+00  1.000000e+00  0.000000e+00  8.900000e+01
# max    1.391593e+06  1.000000e+01  3.449500e+04  3.000000e+09  1.440000e+04
#
#              budget    popularity
# count  1.136234e+06  1.136234e+06
# mean   2.685613e+05  1.235246e+00
# std    5.075180e+06  7.588475e+00
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  6.000000e-01
# 50%    0.000000e+00  6.000000e-01
# 75%    0.000000e+00  8.770000e-01
# max    1.000000e+09  2.994357e+03

# %% [markdown]
# ## Remove the titles without enlglish names.

# %%
df = df[df['title'].apply(lambda x: bool(re.match(r'^[A-Za-z0-9\s.,!?\'"-]+$', str(x))))]
df.shape[0]
# Out:
# 873684

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               id                    title  vote_average  vote_count    status  \
# 0          27205                Inception         8.364       34495  Released
# 1         157336             Interstellar         8.417       32571  Released
# 2            155          The Dark Knight         8.512       30619  Released
# 3          19995                   Avatar         7.573       29815  Released
# 4          24428             The Avengers         7.710       29166  Released
# ...          ...                      ...           ...         ...       ...
# 1136229   732895  200 Cigarettes from Now         0.000           0  Released
# 1136230   732896            Dear Aunt Noa         0.000           0  Released
# 1136231   732897                 Aye, Boy         0.000           0  Released
# 1136232   732898              The Turtles         0.000           0  Released
# 1136233  1391127            Psycho Lovers         0.000           0  Released
#
#         release_date     revenue  runtime  adult  \
# 0         2010-07-15   825532764      148  False
# 1         2014-11-05   701729206      169  False
# 2         2008-07-16  1004558444      152  False
# 3         2009-12-15  2923706026      162  False
# 4         2012-04-25  1518815515      143  False
# ...              ...         ...      ...    ...
# 1136229   2021-06-02           0       45  False
# 1136230          NaN           0       11  False
# 1136231   2020-09-17           0       19  False
# 1136232   2021-12-04           0       15  False
# 1136233          NaN           0        0  False
#
#                             backdrop_path  ...           original_title  \
# 0        /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...                Inception
# 1        /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...             Interstellar
# 2        /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...          The Dark Knight
# 3        /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...                   Avatar
# 4        /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...             The Avengers
# ...                                   ...  ...                      ...
# 1136229                               NaN  ...  200 Cigarettes from Now
# 1136230                               NaN  ...            Dear Aunt Noa
# 1136231                               NaN  ...                 Aye, Boy
# 1136232                               NaN  ...              The Turtles
# 1136233                               NaN  ...            Psycho Lovers
#
#                                                   overview popularity  \
# 0        Cobb, a skilled thief who commits corporate es...     83.952
# 1        The adventures of a group of explorers who mak...    140.241
# 2        Batman raises the stakes in his war on crime. ...    130.643
# 3        In the 22nd century, a paraplegic Marine is di...     79.932
# 4        When an unexpected enemy emerges and threatens...     98.082
# ...                                                    ...        ...
# 1136229  Fall 2019, Xia gaps from college and moves to ...      0.600
# 1136230  A transgender environmentalist from LA and a s...      0.600
# 1136231  In this coming-of-age story inspired by true e...      0.600
# 1136232  When the introverted Emma meets the bubbly Jea...      0.600
# 1136233                                                NaN      0.650
#
#                               poster_path  \
# 0        /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1        /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2        /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3        /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4         /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# ...                                   ...
# 1136229  /ecNNCEVrLJoA3crnimvSuAOw1AD.jpg
# 1136230  /3apMpTgBZhKa9PfikUJjL4hon2I.jpg
# 1136231  /tFxO95u5pENsCXpWhBeViWtAtNk.jpg
# 1136232  /mjJr5WYKLSArB8N7KY8iiIKctFt.jpg
# 1136233  /hO5MuddCPHDX58gPw2gR4Hp2lFC.jpg
#
#                                                    tagline  \
# 0                     Your mind is the scene of the crime.
# 1        Mankind was born on Earth. It was never meant ...
# 2                        Welcome to a world without rules.
# 3                              Enter the world of Pandora.
# 4                                  Some assembly required.
# ...                                                    ...
# 1136229                                                NaN
# 1136230                                                NaN
# 1136231                                                NaN
# 1136232                                                NaN
# 1136233                                                NaN
#
#                                               genres  \
# 0                 Action, Science Fiction, Adventure
# 1                  Adventure, Drama, Science Fiction
# 2                     Drama, Action, Crime, Thriller
# 3        Action, Adventure, Fantasy, Science Fiction
# 4                 Science Fiction, Action, Adventure
# ...                                              ...
# 1136229                       Comedy, Drama, Romance
# 1136230                                          NaN
# 1136231                                          NaN
# 1136232                                       Comedy
# 1136233                                          NaN
#
#                                       production_companies  \
# 0        Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1        Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2        DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3        Dune Entertainment, Lightstorm Entertainment, ...
# 4                                           Marvel Studios
# ...                                                    ...
# 1136229                                                NaN
# 1136230                                                NaN
# 1136231                                                NaN
# 1136232                                                NaN
# 1136233                                                NaN
#
#                              production_countries  \
# 0        United Kingdom, United States of America
# 1        United Kingdom, United States of America
# 2        United Kingdom, United States of America
# 3        United States of America, United Kingdom
# 4                        United States of America
# ...                                           ...
# 1136229           China, United States of America
# 1136230                                       NaN
# 1136231                                       NaN
# 1136232                            United Kingdom
# 1136233                                       NaN
#
#                            spoken_languages  \
# 0        English, French, Japanese, Swahili
# 1                                   English
# 2                         English, Mandarin
# 3                          English, Spanish
# 4                   English, Hindi, Russian
# ...                                     ...
# 1136229                 Cantonese, Mandarin
# 1136230                                 NaN
# 1136231                                 NaN
# 1136232                             English
# 1136233                                 NaN
#
#                                                   keywords
# 0        rescue, mission, dream, airplane, paris, franc...
# 1        rescue, future, spacecraft, race against time,...
# 2        joker, sadism, chaos, secret identity, crime f...
# 3        future, society, culture clash, space travel, ...
# 4        new york city, superhero, shield, based on com...
# ...                                                    ...
# 1136229                                                NaN
# 1136230                                                NaN
# 1136231                                                NaN
# 1136232                                                NaN
# 1136233                                                NaN
#
# [873684 rows x 24 columns]>

# %%
top_rated_movies = df[['title', 'vote_average']].sort_values(by='vote_average', ascending=False).head(10)
top_rated_movies
# Out:
#                                           title  vote_average
# 310493                          Khoon Ki Pukaar          10.0
# 227450                   Gangsters in the Ocean          10.0
# 299137                                  mondano          10.0
# 258823                             Kyoei Branko          10.0
# 299148                        Le Regard Tairraz          10.0
# 299153  THE TRUE RELIGION by RICK S RUTH ARTIST          10.0
# 258822                                   Bounty          10.0
# 299167                                 Cortland          10.0
# 299175                      We're Sitting Good!          10.0
# 299179                   Abducted on Prom Night          10.0

# %%
df.describe()
# Out:
#                  id   vote_average     vote_count       revenue  \
# count  8.736840e+05  873684.000000  873684.000000  8.736840e+05
# mean   7.190411e+05       1.968239      21.063433  7.131734e+05
# std    3.935882e+05       3.030796     328.987282  1.708671e+07
# min    2.000000e+00       0.000000       0.000000 -1.200000e+01
# 25%    3.912575e+05       0.000000       0.000000  0.000000e+00
# 50%    7.172700e+05       0.000000       0.000000  0.000000e+00
# 75%    1.062945e+06       5.000000       1.000000  0.000000e+00
# max    1.391593e+06      10.000000   34495.000000  3.000000e+09
#
#              runtime        budget     popularity
# count  873684.000000  8.736840e+05  873684.000000
# mean       50.488395  2.905464e+05       1.301974
# std        61.057364  5.027463e+06       8.021203
# min       -28.000000  0.000000e+00       0.000000
# 25%         3.000000  0.000000e+00       0.600000
# 50%        28.000000  0.000000e+00       0.600000
# 75%        90.000000  0.000000e+00       0.926000
# max     14400.000000  1.000000e+09    2994.357000

# %%
extreme_runtime_movies = df[df['runtime'].between(0, 30) | (df['runtime'] > 180)]
extreme_runtime_movies
# Out:
#               id                  title  vote_average  vote_count    status  \
# 17           597                Titanic         7.900       23637  Released
# 93           497         The Green Mile         8.507       15937  Released
# 119          424       Schindler's List         8.573       14594  Released
# 149       273248      The Hateful Eight         7.746       13291  Released
# 215          240  The Godfather Part II         8.591       11293  Released
# ...          ...                    ...           ...         ...       ...
# 1136228   732894           Good Morning         0.000           0  Released
# 1136230   732896          Dear Aunt Noa         0.000           0  Released
# 1136231   732897               Aye, Boy         0.000           0  Released
# 1136232   732898            The Turtles         0.000           0  Released
# 1136233  1391127          Psycho Lovers         0.000           0  Released
#
#         release_date     revenue  runtime  adult  \
# 17        1997-11-18  2264162353      194  False
# 93        1999-12-10   286801374      189  False
# 119       1993-12-15   321365567      195  False
# 149       2015-12-25   155760117      188  False
# 215       1974-12-20   102600000      202  False
# ...              ...         ...      ...    ...
# 1136228   2020-04-05           0       13  False
# 1136230          NaN           0       11  False
# 1136231   2020-09-17           0       19  False
# 1136232   2021-12-04           0       15  False
# 1136233          NaN           0        0  False
#
#                             backdrop_path  ...         original_title  \
# 17       /rzdPqYx7Um4FUZeD8wpXqjAUcEm.jpg  ...                Titanic
# 93       /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg  ...         The Green Mile
# 119      /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  ...       Schindler's List
# 149      /7gfDVfaw0VaIkUGiEH13o3TIC7A.jpg  ...      The Hateful Eight
# 215      /kGzFbGhp99zva6oZODW5atUtnqi.jpg  ...  The Godfather Part II
# ...                                   ...  ...                    ...
# 1136228                               NaN  ...           Good Morning
# 1136230                               NaN  ...          Dear Aunt Noa
# 1136231                               NaN  ...               Aye, Boy
# 1136232                               NaN  ...            The Turtles
# 1136233                               NaN  ...          Psycho Lovers
#
#                                                   overview popularity  \
# 17       101-year-old Rose DeWitt Bukater tells the sto...    102.348
# 93       A supernatural tale set on death row in a Sout...     83.739
# 119      The true story of how businessman Oskar Schind...     65.084
# 149      Bounty hunters seek shelter from a raging bliz...     32.119
# 215      In the continuing saga of the Corleone crime f...     64.753
# ...                                                    ...        ...
# 1136228  Buzz, buzz. A text comes through and Griff wak...      0.600
# 1136230  A transgender environmentalist from LA and a s...      0.600
# 1136231  In this coming-of-age story inspired by true e...      0.600
# 1136232  When the introverted Emma meets the bubbly Jea...      0.600
# 1136233                                                NaN      0.650
#
#                               poster_path  \
# 17       /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg
# 93       /8VG8fDNiy50H4FedGwdSVUPoaJe.jpg
# 119      /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg
# 149      /jIywvdPjia2t3eKYbjVTcwBQlG8.jpg
# 215      /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg
# ...                                   ...
# 1136228  /3R4Tg4MpgPYtJzrm4tls33kgQTA.jpg
# 1136230  /3apMpTgBZhKa9PfikUJjL4hon2I.jpg
# 1136231  /tFxO95u5pENsCXpWhBeViWtAtNk.jpg
# 1136232  /mjJr5WYKLSArB8N7KY8iiIKctFt.jpg
# 1136233  /hO5MuddCPHDX58gPw2gR4Hp2lFC.jpg
#
#                                                    tagline  \
# 17               Nothing on Earth could come between them.
# 93                                     Miracles do happen.
# 119        Whoever saves one life, saves the world entire.
# 149       No one comes up here without a damn good reason.
# 215      I don't feel I have to wipe everybody out, Tom...
# ...                                                    ...
# 1136228                                                NaN
# 1136230                                                NaN
# 1136231                                                NaN
# 1136232                                                NaN
# 1136233                                                NaN
#
#                           genres  \
# 17                Drama, Romance
# 93         Fantasy, Drama, Crime
# 119          Drama, History, War
# 149      Drama, Mystery, Western
# 215                 Drama, Crime
# ...                          ...
# 1136228                      NaN
# 1136230                      NaN
# 1136231                      NaN
# 1136232                   Comedy
# 1136233                      NaN
#
#                                       production_companies  \
# 17       Paramount, 20th Century Fox, Lightstorm Entert...
# 93       Castle Rock Entertainment, Darkwoods Productio...
# 119                                   Amblin Entertainment
# 149      The Weinstein Company, Double Feature Films, F...
# 215                         Paramount, The Coppola Company
# ...                                                    ...
# 1136228                                                NaN
# 1136230                                                NaN
# 1136231                                                NaN
# 1136232                                                NaN
# 1136233                                                NaN
#
#              production_countries  \
# 17       United States of America
# 93       United States of America
# 119      United States of America
# 149      United States of America
# 215      United States of America
# ...                           ...
# 1136228                       NaN
# 1136230                       NaN
# 1136231                       NaN
# 1136232            United Kingdom
# 1136233                       NaN
#
#                                           spoken_languages  \
# 17       English, French, German, Swedish, Italian, Rus...
# 93                                         French, English
# 119                        German, Polish, Hebrew, English
# 149                                       Spanish, English
# 215                       English, Italian, Latin, Spanish
# ...                                                    ...
# 1136228                                                NaN
# 1136230                                                NaN
# 1136231                                                NaN
# 1136232                                            English
# 1136233                                                NaN
#
#                                                   keywords
# 17       epic, ship, drowning, panic, shipwreck, evacua...
# 93       mentally disabled, based on novel or book, sou...
# 119      factory, hero, based on novel or book, nazi, c...
# 149      bounty hunter, wyoming, usa, narration, mounta...
# 215      italian american, cuba, italy, gangster, prais...
# ...                                                    ...
# 1136228                                                NaN
# 1136230                                                NaN
# 1136231                                                NaN
# 1136232                                                NaN
# 1136233                                                NaN
#
# [461186 rows x 24 columns]

# %%
df = df.dropna()
df.shape
# Out:
# (8203, 24)

# %%
most_popular_movies = df[['title', 'popularity']].sort_values(by='popularity', ascending=False).head(10)
most_popular_movies
# Out:
#                      title  popularity
# 3871           Blue Beetle    2994.357
# 5052          Gran Turismo    2680.593
# 7921            The Nun II    1692.778
# 9968           Retribution    1547.220
# 4014            Talk to Me    1458.514
# 1110                Fast X    1175.267
# 6397      Sound of Freedom    1111.036
# 825                 Barbie    1069.340
# 1799             Elemental    1008.942
# 8194  No One Will Save You     961.212

# %%
language_distribution = df['spoken_languages'].value_counts()
language_distribution
# Out:
# spoken_languages
# English                                        5269
# Japanese                                        226
# English, Spanish                                169
# Spanish                                         169
# English, French                                 132
#                                                ...
# Swahili, English                                  1
# Arabic, English, Turkish, German                  1
# Mandarin, English, French, Spanish, Russian       1
# English, Spanish, Hungarian                       1
# Czech, English, French                            1
# Name: count, Length: 839, dtype: int64

# %%
correlation_matrix = df[['vote_average', 'revenue', 'runtime', 'popularity']].corr()
correlation_matrix
# Out:
#               vote_average   revenue   runtime  popularity
# vote_average      1.000000  0.146244  0.269345    0.090396
# revenue           0.146244  1.000000  0.213858    0.219476
# runtime           0.269345  0.213858  1.000000    0.114673
# popularity        0.090396  0.219476  0.114673    1.000000

# %%
high_revenue_genres = df.explode('genres').groupby('genres')['revenue'].mean().sort_values(ascending=False)
high_revenue_genres
# Out:
# genres
# Animation, Family, Adventure, Fantasy, Comedy    1.355725e+09
# Family, Fantasy, Romance                         1.266116e+09
# Action, Animation, Comedy, Family, Adventure     1.031553e+09
# Drama, Action, Crime, Thriller                   1.004558e+09
# Action, Adventure, Fantasy, Science Fiction      9.745687e+08
#                                                      ...
# Drama, Crime, Action                             0.000000e+00
# Drama, Crime, Fantasy, Thriller                  0.000000e+00
# Drama, Crime, Music                              0.000000e+00
# Drama, Documentary                               0.000000e+00
# Western, Thriller                                0.000000e+00
# Name: revenue, Length: 1705, dtype: float64

# %%
top_revenue = df[['title', 'revenue']].sort_values(by='revenue', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x='revenue', y='title', data=top_revenue, palette="viridis")
plt.title("Top 10 Movies by Revenue", fontsize=16)
plt.xlabel("Revenue", fontsize=12)
plt.ylabel("Movie Title", fontsize=12)
plt.show()
# Out:
# /var/folders/cv/57_q_p5n4cncc53s74r1mjy80000gn/T/ipykernel_30886/1048683704.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='revenue', y='title', data=top_revenue, palette="viridis")

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='popularity', y='revenue', data=df, alpha=0.7, color='purple')
plt.title("Revenue vs Popularity", fontsize=16)
plt.xlabel("Popularity", fontsize=12)
plt.ylabel("Revenue", fontsize=12)
plt.show()
